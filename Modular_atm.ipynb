# %% [markdown]
# <a href="https://colab.research.google.com/github/jdowtin655-cmd/JamauriD/blob/main/Modular_atm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# IMPORT STATEMENTS
# (None)

# FUNCTION DEFINITIONS

# 1. verify_pin()
#    Create a loop
#    Ask user for PIN
#    Keep asking until PIN equals "1234"
#    Return True

# 2. withdraw(balance, amount)
#    Check if amount <= balance
#    If yes:
#        subtract amount from balance
#        return new balance
#    If no:
#        print insufficient funds
#        return original balance


# PROGRAM LOGIC

# 1. Set current_balance = 500
# 2. Call verify_pin()
# 3. Ask user for withdrawal amount
# 4. Update current_balance by calling withdraw()
# 5. Print final balance

# STRUCTURE & PSEUDOCODE

def verify_pin():
    while True:
        pin = input("Enter your PIN: ")
        if pin == "1234":
            print("PIN accepted.")
            return True
        else:
            print("Incorrect PIN. Try again.")

# Call function at bottom
verify_pin()

# FUNCTION DEFINITIONS

def verify_pin():
    while True:
        pin = input("Enter your PIN: ")
        if pin == "1234":
            print("PIN accepted.")
            return True
        else:
            print("Incorrect PIN. Try again.")

def withdraw(balance, amount):
    if amount <= balance:
        balance -= amount
        print("Withdrawal successful.")
        return balance
    else:
        print("Insufficient funds.")
        return balance


# PROGRAM LOGIC

current_balance = 500

verify_pin()

amount = float(input("Enter withdrawal amount: "))

current_balance = withdraw(current_balance, amount)

print("Final balance:", current_balance)
# Out:
# Enter your PIN: 0000
# Incorrect PIN. Try again.
# Enter your PIN: 1234
# PIN accepted.
# Enter your PIN: 1234
# PIN accepted.
# Enter withdrawal amount: 150.0
# Withdrawal successful.
# Final balance: 350.0
