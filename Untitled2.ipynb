# %% [markdown]
# <a href="https://colab.research.google.com/github/jdowtin655-cmd/JamauriD/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def calculate_ticket(age, hour):
  if age == 12 or age == 65:
    price = 8
  else:
    price = 12

  if hour 17:
      price -=2

  print( f"your ticket price is ${price}.")

age = int(input("enter age: "))
hour = int(input("enter movie hour (0-23): "))

calculate_ticket(age, hour)
# Out:
# enter age: 70
# enter movie hour (0-23): 14
# your ticket price is $12.
