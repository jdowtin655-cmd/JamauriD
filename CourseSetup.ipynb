# %% [markdown]
# <a href="https://colab.research.google.com/github/jdowtin655-cmd/JamauriD/blob/main/CourseSetup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# This is my first Python comment

# %%
# Hey this is my second python comment.
